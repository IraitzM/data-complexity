# %%
import json
import dcm
import numpy as np

n_samples = 300
n = 1 # trials
p = 0.5
y = np.random.binomial(n, p, n_samples)

x1 = np.random.random(n_samples)
x2 = 0.5+(-1+y)*0.20 # x2 sets 0 samples on 0.20 value and 1 on 0.70

X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
from dcm import NeighborhoodMeasures

nmeans = NeighborhoodMeasures()
nmeans.fit(X,y)
# Out:
# NeighborhoodMeasures(measures=['N1', 'N2', 'N3', 'N4', 'N5', 'N6'])

# %%
nmeans.transform(X, y)
# Out:
# {'N1': np.float64(0.0033333333333333335),
#  'N2': {'mean': np.float64(0.017666354773271605),
#   'std': np.float64(0.01687208717368816)},
#  'N3': np.float64(0.0),
#  'N4': np.float64(0.47333333333333333),
#  'N5': 0.05,
#  'N6': np.float64(0.8145666666666667)}
