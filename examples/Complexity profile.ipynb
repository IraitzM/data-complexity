# %%
from dcm.utils import gen_datasets

first, second, third, fourth, fifth = gen_datasets(proportion=0.01)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=first["X"][:, 0], y=first["X"][:, 1], alpha=0.6, hue=first["y"], palette="deep")
plt.show()

# %%
from dcm import ComplexityProfile

profile = ComplexityProfile()
profile.fit(first["X"],first["y"])
profile.transform(return_type="df")
# Out:
#     F1       F1v        F2    F3   F4        B1      B2        S1       S2  \
# 0  0.0  0.640224  0.795528  0.39  0.0  0.919207  0.9798  0.018248  0.47253
#
#          S3      S4        C1      C2        N1        N2    N3    N4  \
# 0  0.019803  0.0032  0.080793  0.9798  0.006667  0.009232  0.01  0.49
#
#          N5        N6        L1
# 0  0.023333  0.510956  0.009901

# %%
sns.scatterplot(x=second["X"][:, 0], y=second["X"][:, 1], alpha=0.6, hue=second["y"], palette="deep")
plt.show()

# %%
profile = ComplexityProfile()
profile.fit(second["X"],second["y"])
profile.transform(return_type="df")
# Out:
#          F1       F1v   F2    F3   F4        B1      B2        S1        S2  \
# 0  0.010357  0.000152  0.0  0.39  0.0  0.919207  0.9798  0.018248  0.472508
#
#          S3        S4        C1      C2        N1        N2    N3    N4  \
# 0  0.019803  0.002697  0.080793  0.9798  0.006667  0.005433  0.01  0.51
#
#          N5        N6        L1
# 0  0.016667  0.189022  0.006623

# %%
sns.scatterplot(x=third["X"][:, 0], y=third["X"][:, 1], alpha=0.6, hue=third["y"], palette="deep")
plt.show()

# %%
profile = ComplexityProfile()
profile.fit(third["X"],third["y"])
profile.transform(return_type="df")
# Out:
#          F1       F1v   F2        F3   F4        B1        B2        S1  \
# 0  0.845124  0.049909  0.0  0.239274  0.0  0.919864  0.980002  0.018075
#
#          S2        S3        S4        C1        C2        N1        N2  \
# 0  0.596158  0.016341  0.003265  0.080136  0.980002  0.006601  0.041436
#
#          N3       N4        N5        N6   L1
# 0  0.006601  0.50165  0.009901  0.085863  0.0

# %%
sns.scatterplot(x=fourth["X"][:, 0], y=fourth["X"][:, 1], alpha=0.6, hue=fourth["y"], palette="deep")
plt.show()

# %%
profile = ComplexityProfile()
profile.fit(fourth["X"],fourth["y"])
profile.transform(return_type="df")
# Out:
#          F1       F1v        F2        F3   F4        B1      B2        S1  \
# 0  0.994405  0.859954  0.792453  0.783333  0.0  0.919207  0.9798  0.018248
#
#          S2        S3        S4        C1      C2        N1        N2    N3  \
# 0  0.532419  0.019803  0.004071  0.080793  0.9798  0.006667  0.013628  0.01
#
#          N4        N5        N6        L1
# 0  0.533333  0.083333  0.620289  0.009901

# %%
sns.scatterplot(x=fifth["X"][:, 0], y=fifth["X"][:, 1], alpha=0.6, hue=fifth["y"], palette="deep")
plt.show()

# %%
profile = ComplexityProfile()
profile.fit(fifth["X"],fifth["y"])
profile.transform(return_type="df")
# Out:
#          F1       F1v        F2     F3   F4        B1      B2        S1  \
# 0  0.991875  0.442122  0.568906  0.485  0.0  0.919207  0.9798  0.018248
#
#          S2        S3       S4        C1      C2        N1        N2    N3  \
# 0  0.609269  0.013202  0.00991  0.080793  0.9798  0.016667  0.127937  0.01
#
#          N4        N5        N6        L1
# 0  0.506667  0.196667  0.751478  0.009901
