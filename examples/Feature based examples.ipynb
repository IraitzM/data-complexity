# %%
import numpy as np

n_samples = 300
n = 1 # trials
p = 0.5
y = np.random.binomial(n, p, n_samples)

x1 = np.random.random(n_samples)
x2 = 0.5+(-1+y)*0.20 # x2 sets 0 samples on 0.20 value and 1 on 0.70

X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
from dcm.feature_based import FeatureBasedMeasures

feat = FeatureBasedMeasures()
feat.fit(X, y)
# Out:
# FeatureBasedMeasures(measures=['F1', 'F1v', 'F2', 'F3', 'F4'])

# %%
feat.F1()
# Out:
# 0.08408370274836878

# %%
x1 = np.random.random(n_samples)
x2 = 0.75+y*-1*np.random.normal(0.5, 0.1, n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
feat = FeatureBasedMeasures()
feat.fit(X, y)
feat.F1()
# Out:
# 0.08408370274836878

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=n_samples, centers=2, n_features=2,random_state=0)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
feat = FeatureBasedMeasures()
feat.fit(X, y)
feat.F1()
# Out:
# 0.22705874599435613

# %%
x1 = np.random.random(n_samples)
x2 = x1+(y-1)*0.2
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
feat = FeatureBasedMeasures()
feat.fit(X, y)
feat.F1()
# Out:
# 0.8687130566052504

# %%
x1 = np.random.random(n_samples)
x2 = np.random.random(n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
feat = FeatureBasedMeasures()
feat.fit(X, y)
feat.F1()
# Out:
# 0.9991061471744626
