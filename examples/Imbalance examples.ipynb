# %%
import numpy as np

n_samples = 300
n = 1 # trials
p = 0.5
y = np.random.binomial(n, p, n_samples)

x1 = np.random.random(n_samples)
x2 = 0.5+(-1+y)*0.20 # x2 sets 0 samples on 0.20 value and 1 on 0.70

X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
from dcm import ImbalanceMeasures

imb = ImbalanceMeasures()
imb.fit(X,y)
imb.transform()
# Out:
# {'C1': np.float64(0.9979471932237238), 'C2': 0.005672753057968549}

# %%
x1 = np.random.random(n_samples)
x2 = 0.75+y*-1*np.random.normal(0.5, 0.1, n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
imb = ImbalanceMeasures()
imb.fit(X,y)
imb.transform()
# Out:
# {'C1': np.float64(0.9979471932237238), 'C2': 0.005672753057968549}

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=n_samples, centers=2, n_features=2,random_state=0)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
imb = ImbalanceMeasures()
imb.fit(X,y)
imb.transform()
# Out:
# {'C1': np.float64(1.0), 'C2': 0.0}

# %%
x1 = np.random.random(n_samples)
x2 = x1+(y-1)*0.2
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
imb = ImbalanceMeasures()
imb.fit(X,y)
imb.transform()
# Out:
# {'C1': np.float64(1.0), 'C2': 0.0}

# %%
x1 = np.random.random(n_samples)
x2 = np.random.random(n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
imb = ImbalanceMeasures()
imb.fit(X,y)
imb.transform()
# Out:
# {'C1': np.float64(1.0), 'C2': 0.0}
