# %%
import numpy as np

n_samples = 300
n = 1 # trials
p = 0.5
y = np.random.binomial(n, p, n_samples)

x1 = np.random.random(n_samples)
x2 = 0.5+(-1+y)*0.20 # x2 sets 0 samples on 0.20 value and 1 on 0.70

X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
from dcm import BalanceMeasures

bal = BalanceMeasures()
bal.fit(X,y)
bal.transform(X,y)
# Out:
# {'B1': np.float64(0.0005130190491101638),
#  'B2': np.float64(0.0014212115828742267)}

# %%
x1 = np.random.random(n_samples)
x2 = 0.75+y*-1*np.random.normal(0.5, 0.1, n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
bal = BalanceMeasures()
bal.fit(X,y)
bal.transform(X,y)
# Out:
# {'B1': np.float64(0.0005130190491101638),
#  'B2': np.float64(0.0014212115828742267)}

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=n_samples, centers=2, n_features=2,random_state=0)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
bal = BalanceMeasures()
bal.fit(X,y)
bal.transform(X,y)
# Out:
# {'B1': np.float64(0.0), 'B2': np.float64(0.0)}

# %%
x1 = np.random.random(n_samples)
x2 = x1+(y-1)*0.2
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
bal = BalanceMeasures()
bal.fit(X,y)
bal.transform(X,y)
# Out:
# {'B1': np.float64(0.0), 'B2': np.float64(0.0)}

# %%
x1 = np.random.random(n_samples)
x2 = np.random.random(n_samples)
X = np.concatenate((x1[:, None], x2[:, None]), axis=1)

sns.scatterplot(x=X[:, 0], y=X[:, 1], alpha=0.6, hue=y, palette="deep")
plt.show()

# %%
bal = BalanceMeasures()
bal.fit(X,y)
bal.transform(X,y)
# Out:
# {'B1': np.float64(0.0), 'B2': np.float64(0.0)}
